# %% [markdown]
# # Comments
#
# Comments are used in code to explain what the code does, making it easier to understand and maintain. There are single-line comments, which start with #, and multi-line comments, which are enclosed in triple quotes (""").
#
# Python ignores comments during execution—they are not run as part of the program and exist only for human readers.

# %%
# This is a single line comment

"""
This is a multi-line comment.
It can span multiple lines.
"""
# Out:
# I am a \ newline character.
