# %% [markdown]
# ## Exercise 1: String Formatting
#
# Create a book record display with proper formatting.
#
# **Requirements:**
# - Create variables: `title`, `author`, `year`, `price`
# - Use f-strings to format the output
# - Apply string methods (`.upper()`, `.title()`, etc.)
# - Format price to 2 decimal places
#
# **Expected Output:**
# ```
# PYTHON CRASH COURSE
# by Eric Matthes (2019)
# Price: $29.99
# ```

# %%
# Your code here
title = 
author = 
year = 
price = 

# TODO: Format and print the output

# %% [markdown]
# ## Exercise 2: User Input Calculator
#
# Build a simple calculator that gets two numbers from the user and performs all arithmetic operations.
#
# **Requirements:**
# - Use `input()` to get two numbers from user
# - Convert strings to numbers using `int()` or `float()`
# - Calculate: addition, subtraction, multiplication, division, floor division, modulus
# - Display results with clear formatting using f-strings
#
# **Example Output:**
# ```
# Enter first number: 10
# Enter second number: 3
#
# Results:
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 / 3 = 3.33
# 10 // 3 = 3
# 10 % 3 = 1
# ```

# %%
# Your code here
num1 = 
num2 = 

# TODO: Perform all calculations and display results

# %% [markdown]
# ## Exercise 3: String Manipulation
#
# Take a sentence and perform various string operations on it.
#
# **Requirements:**
# - Get a sentence from the user (or use a hardcoded string)
# - Display the sentence in uppercase
# - Display the sentence in lowercase
# - Display the sentence in title case
# - Count and display the number of words (hint: use `.split()`)
# - Replace a specific word with another word
# - Check if a word exists in the sentence
#
# **Example:**
# ```
# Original: Python programming is fun and powerful
# Uppercase: PYTHON PROGRAMMING IS FUN AND POWERFUL
# Lowercase: python programming is fun and powerful
# Title Case: Python Programming Is Fun And Powerful
# Word Count: 6 words
# After Replace: Python coding is fun and powerful
# Contains 'fun': True
# ```

# %%
# Your code here
sentence = 

# TODO: Perform all string operations and display results

# %% [markdown]
# ## Bonus Challenge (Optional)
#
# Create a simple contact card formatter:
#
# **Requirements:**
# - Get name, email, and phone from user
# - Clean up the input (strip whitespace, proper capitalization)
# - Display in a nicely formatted card
#
# **Example Output:**
# ```
# ════════════════════════════
#         CONTACT CARD
# ════════════════════════════
# Name:  Alice Johnson
# Email: alice.johnson@email.com
# Phone: (555) 123-4567
# ════════════════════════════
# ```

# %%
# Bonus challenge - your code here
