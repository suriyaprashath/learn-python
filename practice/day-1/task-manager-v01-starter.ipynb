# %% [markdown]
# ## Part 1: Basic Task Display (20 minutes)
#
# Start by creating some tasks and displaying them nicely.

# %%
# Task Manager v0.1
# Your Name Here
# Day 1 - Python Fundamentals

# Define your tasks
task1 = "Learn Python basics"
task2 = "Practice coding daily"
task3 = "Build a project"

# TODO: Create a separator line using string multiplication
# Hint: "=" * 40 creates a line of 40 equal signs
separator = 

# TODO: Print the header
# Format:
# ========================================
#            MY TASK LIST
# ========================================


# TODO: Print each task with numbering
# Format: 1. Learn Python basics
#         2. Practice coding daily
#         3. Build a project


# TODO: Print footer with total count
# Format:
# ========================================
# Total Tasks: 3
# ========================================

# %% [markdown]
# ## Part 2: Enhanced Formatting (15 minutes)
#
# Make your task list more interesting with string methods and formatting.
#
# **Ideas to try:**
# - Convert task titles to uppercase
# - Add status labels (TODO, IN PROGRESS, DONE)
# - Use different separator characters
# - Center the header text

# %%
# Enhanced version - your code here

# Example: Add status to tasks
task1 = "Learn Python basics"
task1_status = "IN PROGRESS"

task2 = "Practice coding daily"
task2_status = "TODO"

task3 = "Build a project"
task3_status = "TODO"

# TODO: Display tasks with status
# Example output:
# 1. [IN PROGRESS] Learn Python basics
# 2. [TODO] Practice coding daily
# 3. [TODO] Build a project

# %% [markdown]
# ## Part 3: Stretch Goals (Optional - 10 minutes)
#
# If you finish early, try these bonus features:
#
# ### Option 1: Add Priority Levels
# ```python
# task1 = "Learn Python basics"
# task1_priority = "HIGH"
# ```
#
# ### Option 2: Add Emojis
# ```python
# # ✅ DONE
# # ⏰ IN PROGRESS
# # 🔴 TODO
# ```
#
# ### Option 3: Add Due Dates
# ```python
# task1_due = "Jan 20, 2026"
# ```

# %%
# Stretch goals - your code here
# Pick one or more ideas above and implement them!

# %% [markdown]
# ## Expected Output Example
#
# Your final output should look something like this (can be different based on your creativity!):
#
# ```
# ========================================
#            MY TASK LIST
# ========================================
# 1. Learn Python basics
# 2. Practice coding daily
# 3. Build a project
# ========================================
# Total Tasks: 3
# ========================================
# ```
#
# Or with enhancements:
#
# ```
# ========================================
#            MY TASK LIST
# ========================================
# 1. [HIGH] ⏰ LEARN PYTHON BASICS
# 2. [MED]  🔴 PRACTICE CODING DAILY
# 3. [LOW]  🔴 BUILD A PROJECT
# ========================================
# Total: 3 tasks | In Progress: 1
# ========================================
# ```
