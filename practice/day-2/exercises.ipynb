# %% [markdown]
# # Day 2 Practice Exercises
#
# **Topics Covered:** Conditionals, Loops, Functions
#
# **Instructions:**
# - Work through each exercise in order
# - Try to solve them independently first
# - If stuck, ask your instructor or pair with a classmate
# - Test your code with different inputs
#
# ---

# %% [markdown]
# ## Exercise 1: Age Category Checker (Conditionals)
#
# **Goal:** Write code that categorizes a person's age.
#
# **Requirements:**
# - Create a variable `age` with any number
# - Use `if/elif/else` to print the category:
#   - 0-12: "Child"
#   - 13-19: "Teenager"
#   - 20-59: "Adult"
#   - 60+: "Senior"
#
# **Example:**
# ```python
# age = 25
# # Output: Adult
# ```

# %%
# Your code here
age = 25

# %% [markdown]
# ## Exercise 2: Grade Calculator (Conditionals + Logical Operators)
#
# **Goal:** Calculate a letter grade based on score and check if the student passed.
#
# **Requirements:**
# - Create a variable `score` (0-100)
# - Assign letter grade:
#   - 90-100: "A"
#   - 80-89: "B"
#   - 70-79: "C"
#   - 60-69: "D"
#   - Below 60: "F"
# - Print the grade
# - Use a second `if` statement to check if `score >= 60`, print "Passed!" or "Failed!"
#
# **Example:**
# ```python
# score = 85
# # Output:
# # Grade: B
# # Passed!
# ```

# %%
# Your code here
score = 85

# %% [markdown]
# ## Exercise 3: Multiplication Table (For Loops)
#
# **Goal:** Print the multiplication table for a given number.
#
# **Requirements:**
# - Create a variable `number` (e.g., 5)
# - Use a `for` loop with `range(1, 11)` to print the multiplication table
# - Format: `5 x 1 = 5`
#
# **Example Output (for number = 5):**
# ```
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# ...
# 5 x 10 = 50
# ```

# %%
# Your code here
number = 5

# %% [markdown]
# ## Exercise 4: Number Guessing Game (While Loops + Break)
#
# **Goal:** Create a simple number guessing game.
#
# **Requirements:**
# - Set a `target_number` (e.g., 7)
# - Create a variable `guess` starting at 0
# - Use a `while` loop that continues until `guess == target_number`
# - Inside the loop:
#   - Increment `guess` by 1
#   - Print "Trying {guess}..."
#   - If `guess == target_number`, print "Found it!" and `break`
#   - Otherwise, print "Not yet..."
#
# **Example Output (for target_number = 3):**
# ```
# Trying 1...
# Not yet...
# Trying 2...
# Not yet...
# Trying 3...
# Found it!
# ```
#
# **Hint:** Start with a simple version where `guess` increments from 1. This simulates guessing sequentially.

# %%
# Your code here
target_number = 7
guess = 0

# %% [markdown]
# ## Exercise 5: Temperature Converter Function
#
# **Goal:** Create a function that converts Celsius to Fahrenheit.
#
# **Requirements:**
# - Define a function `celsius_to_fahrenheit(celsius)`
# - Formula: `fahrenheit = (celsius * 9/5) + 32`
# - The function should `return` the Fahrenheit value
# - Test it with a few values and print the results
#
# **Example:**
# ```python
# result = celsius_to_fahrenheit(0)
# print(f"0°C is {result}°F")  # Output: 0°C is 32.0°F
#
# result = celsius_to_fahrenheit(100)
# print(f"100°C is {result}°F")  # Output: 100°C is 212.0°F
# ```

# %%
# Your code here
def celsius_to_fahrenheit(celsius):
    # Add your code here
    pass

# Test your function
print(celsius_to_fahrenheit(0))
print(celsius_to_fahrenheit(100))

# %% [markdown]
# ## Exercise 6: Calculator with Multiple Functions
#
# **Goal:** Create a simple calculator with separate functions for each operation.
#
# **Requirements:**
# - Create 4 functions: `add(a, b)`, `subtract(a, b)`, `multiply(a, b)`, `divide(a, b)`
# - Each function should return the result of the operation
# - For `divide`, check if `b == 0` and return a message like "Cannot divide by zero" instead of dividing
# - Test all functions with sample values
#
# **Example:**
# ```python
# print(add(10, 5))       # 15
# print(subtract(10, 5))  # 5
# print(multiply(10, 5))  # 50
# print(divide(10, 5))    # 2.0
# print(divide(10, 0))    # Cannot divide by zero
# ```

# %%
# Your code here
def add(a, b):
    # Add your code here
    pass

def subtract(a, b):
    # Add your code here
    pass

def multiply(a, b):
    # Add your code here
    pass

def divide(a, b):
    # Add your code here
    pass

# Test your functions
print(add(10, 5))
print(subtract(10, 5))
print(multiply(10, 5))
print(divide(10, 5))
print(divide(10, 0))

# %% [markdown]
# ## 🌟 Bonus Exercise: Scope Explorer
#
# **Goal:** Understand local vs global scope with a practical example.
#
# **Requirements:**
# - Create a global variable `counter = 0`
# - Create a function `increment_counter()` that:
#   - Uses the `global` keyword to modify the global `counter`
#   - Increments `counter` by 1
#   - Prints the new value
# - Call the function 3 times and observe the counter increasing
# - Print the final value of `counter` outside the function
#
# **Example Output:**
# ```
# Counter: 1
# Counter: 2
# Counter: 3
# Final counter: 3
# ```

# %%
# Your code here
counter = 0

def increment_counter():
    # Add your code here
    pass

# Test your function
increment_counter()
increment_counter()
increment_counter()
print(f"Final counter: {counter}")

# %% [markdown]
# ---
#
# ## 🎉 Great Work!
#
# You've practiced:
# - ✅ Conditionals (if/elif/else)
# - ✅ Loops (for and while)
# - ✅ Functions (def, parameters, return)
# - ✅ Loop control (break)
# - ✅ Variable scope (global keyword)
#
# **Next:** Try the Task Manager v0.2 project to combine all these concepts!
