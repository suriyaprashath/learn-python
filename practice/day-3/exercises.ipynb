# %% [markdown]
# # Day 3 Practice Exercises

# %% [markdown]
# ---
# ## Exercise 1: Shopping List Manager (Lists)
#
# **Concepts:** Lists, append, remove, loops
#
# **Task:**
# 1. Create an empty list called `shopping_list`
# 2. Add these items: "milk", "bread", "eggs", "butter"
# 3. Add "cheese" to the list
# 4. Remove "bread" from the list
# 5. Print each item with its number (use enumerate)
# 6. Print the total number of items
#
# **Expected output:**
# ```
# Shopping List:
# 1. milk
# 2. eggs
# 3. butter
# 4. cheese
# Total items: 4
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 2: Student Records (Dictionaries)
#
# **Concepts:** Dictionaries, accessing values, get() method
#
# **Task:**
# 1. Create a dictionary called `student` with:
#    - name: "Alice"
#    - age: 20
#    - grade: "A"
#    - subjects: ["Math", "Science", "English"]
# 2. Print the student's name and grade
# 3. Add a new key "email" with value "alice@school.com"
# 4. Try to access "phone" using get() with default "Not provided"
# 5. Print all keys and values using .items()
#
# **Expected output:**
# ```
# Name: Alice
# Grade: A
# Phone: Not provided
#
# All information:
# name: Alice
# age: 20
# grade: A
# subjects: ['Math', 'Science', 'English']
# email: alice@school.com
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 3: Coordinate System (Tuples)
#
# **Concepts:** Tuples, immutability, tuple unpacking
#
# **Task:**
# 1. Create a tuple called `point1` with coordinates (10, 20)
# 2. Create a tuple called `point2` with coordinates (30, 40)
# 3. Unpack `point1` into variables `x1` and `y1`
# 4. Unpack `point2` into variables `x2` and `y2`
# 5. Calculate the distance between points using: `sqrt((x2-x1)**2 + (y2-y1)**2)`
#    - Import math module and use math.sqrt()
# 6. Print the points and distance
#
# **Expected output:**
# ```
# Point 1: (10, 20)
# Point 2: (30, 40)
# Distance: 28.28
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 4: Remove Duplicates (Sets)
#
# **Concepts:** Sets, converting between list and set, set operations
#
# **Task:**
# 1. You have a list: `numbers = [1, 2, 3, 2, 4, 5, 1, 6, 3, 7, 4]`
# 2. Convert it to a set to remove duplicates
# 3. Convert back to a sorted list
# 4. Create two sets:
#    - `set_a = {1, 2, 3, 4, 5}`
#    - `set_b = {4, 5, 6, 7, 8}`
# 5. Find and print:
#    - Common elements (intersection)
#    - All unique elements (union)
#    - Elements only in set_a (difference)
#
# **Expected output:**
# ```
# Original list: [1, 2, 3, 2, 4, 5, 1, 6, 3, 7, 4]
# Unique sorted: [1, 2, 3, 4, 5, 6, 7]
#
# Common elements: {4, 5}
# All unique elements: {1, 2, 3, 4, 5, 6, 7, 8}
# Only in set_a: {1, 2, 3}
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 5: Grade Book (Lists + Dictionaries)
#
# **Concepts:** List of dictionaries, loops, accessing nested data
#
# **Task:**
# 1. Create a list called `students` with these dictionaries:
#    - {"name": "Alice", "score": 85}
#    - {"name": "Bob", "score": 92}
#    - {"name": "Charlie", "score": 78}
#    - {"name": "Diana", "score": 95}
# 2. Loop through students and print each name and score
# 3. Calculate and print the average score
# 4. Find and print the highest score and student name
# 5. Count how many students scored 80 or above
#
# **Expected output:**
# ```
# Student Grades:
# Alice: 85
# Bob: 92
# Charlie: 78
# Diana: 95
#
# Average score: 87.5
# Highest score: Diana with 95
# Students with 80+: 3
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 6: Word Counter (Dictionaries + Loops)
#
# **Concepts:** Dictionaries for counting, get() method, loops
#
# **Task:**
# 1. You have a sentence: `"the quick brown fox jumps over the lazy dog the fox"`
# 2. Split the sentence into words
# 3. Create a dictionary to count how many times each word appears
#    - Use .get() method: `count[word] = count.get(word, 0) + 1`
# 4. Print each word and its count
# 5. Find and print the most common word
#
# **Expected output:**
# ```
# Word counts:
# the: 3
# quick: 1
# brown: 1
# fox: 2
# jumps: 1
# over: 1
# lazy: 1
# dog: 1
#
# Most common word: 'the' appears 3 times
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## Exercise 7: Random Data Generator (Modules)
#
# **Concepts:** Importing modules, using module functions
#
# **Task:**
# 1. Import the `random` module
# 2. Generate a random number between 1 and 100
# 3. Create a list of 5 random numbers between 1 and 50
# 4. Pick a random item from the list: `["apple", "banana", "cherry", "date"]`
# 5. Create a list of numbers 1-10 and shuffle it
# 6. Import `math` module and calculate:
#    - Square root of 144
#    - 2 raised to power of 8
#
# **Expected output (will vary due to randomness):**
# ```
# Random number: 67
# Random list: [23, 45, 12, 38, 5]
# Random fruit: cherry
# Shuffled: [3, 7, 1, 9, 5, 2, 10, 4, 8, 6]
#
# Square root of 144: 12.0
# 2^8: 256.0
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## 🎯 Bonus Exercise: Contact Book (All Concepts)
#
# **Concepts:** Lists, dictionaries, tuples, sets, loops
#
# **Task:**
# 1. Create a list called `contacts` with these dictionaries:
#    - {"name": "Alice", "phone": "555-1234", "email": "alice@email.com", "tags": {"friend", "work"}}
#    - {"name": "Bob", "phone": "555-5678", "email": "bob@email.com", "tags": {"family"}}
#    - {"name": "Charlie", "phone": "555-9012", "email": "charlie@email.com", "tags": {"friend", "school"}}
# 2. Print all contacts in a formatted way
# 3. Find all unique tags across all contacts (use set union)
# 4. Find contacts that have the "friend" tag
# 5. Create a function `find_contact(name)` that returns the contact's phone and email as a tuple
#    - Return (None, None) if not found
#
# **Expected output:**
# ```
# Contact List:
# =============
# Name: Alice
# Phone: 555-1234
# Email: alice@email.com
# Tags: friend, work
#
# Name: Bob
# Phone: 555-5678
# Email: bob@email.com
# Tags: family
#
# Name: Charlie
# Phone: 555-9012
# Email: charlie@email.com
# Tags: friend, school
#
# All tags: {'family', 'friend', 'school', 'work'}
#
# Friends: Alice, Charlie
#
# Looking up Bob: (555-5678, bob@email.com)
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## Next Steps
#
# Once you've completed these exercises:
# 1. ✅ Check your solutions against the solution notebook
# 2. ✅ Move on to **Task Manager v0.3** project
