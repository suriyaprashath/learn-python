# %% [markdown]
# # Install VS Code
# Download URL - https://code.visualstudio.com/download

# %% [markdown]
# # VS Code Essentials
#
# 1. Open a folder from context menu
# 1. Unsaved files will have a dot in the tab
# 1. Inbuilt terminal - open with ``Ctrl + ` ``

# %% [markdown]
# # Pending topics
#
# 1. Install extensions
# 1. Setup virtual environment
