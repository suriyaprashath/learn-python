# %% [markdown]
# # Install Python
#
# Download URL - https://www.python.org/downloads/
#
# Run `python --version` to verify the installation

# %% [markdown]
# # Python Commands Overview
# `py` is a windows specific python launcher that allows you to select and launch different installed versions of Python easily. For example, `py -3.8` will launch Python 3.8 if it is installed.
